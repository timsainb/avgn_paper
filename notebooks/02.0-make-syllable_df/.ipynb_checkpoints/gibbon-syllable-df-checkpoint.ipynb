# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm.autonotebook import tqdm
from joblib import Parallel, delayed
#import umap
import pandas as pd
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
import librosa

# %%
from avgn.utils.paths import DATA_DIR, most_recent_subdirectory, ensure_dir

# %%
DATASET_ID = 'gibbon_morita_segmented'

# %%
from avgn.utils.hparams import HParams
from avgn.dataset import DataSet

# %%
from avgn.signalprocessing.create_spectrogram_dataset import prepare_wav, create_label_df, get_row_audio

# %% [markdown]
# ### create dataset

# %%
hparams = HParams(
    num_mel_bins = 32,
    mel_lower_edge_hertz=50,
    mel_upper_edge_hertz=7999,
    butter_lowcut = 50,
    butter_highcut = 7999,
    ref_level_db = 20,
    min_level_db = -65,
    mask_spec = True,
    win_length_ms = 10,
    hop_length_ms = 2,
    mask_spec_kwargs = {"spec_thresh": 0.9, "offset": 1e-10},
    nex=-1,
    n_jobs=-1,
    verbosity = 1,
)

# %%
# create a dataset object
dataset = DataSet(DATASET_ID, hparams = hparams)
# Out:
# HBox(children=(IntProgress(value=0, description='loading json', max=128, style=ProgressStyle(description_width…
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 128 out of 128 | elapsed:    0.1s finished
# HBox(children=(IntProgress(value=0, description='getting unique individuals', max=128, style=ProgressStyle(des…

# %%
dataset.sample_json
# Out:
# OrderedDict([('datetime', '2017-09-12_07-00-02'),
#              ('species', 'Hylobatidae'),
#              ('common_name', 'Gibbon'),
#              ('samplerate_hz', 16000),
#              ('original_wav',
#               '/mnt/cube/tsainbur/Projects/github_repos/avgn_paper/data/raw/gibbon_morita/gibbon_superregular_data/test_data/20170912-070002_01_ch.wav'),
#              ('length_s', 1800.0),
#              ('wav_loc',
#               '/mnt/cube/tsainbur/Projects/github_repos/avgn_paper/data/raw/gibbon_morita/gibbon_superregular_data/test_data/20170912-070002_01_ch.wav'),
#              ('indvs',
#               OrderedDict([('UNK',
#                             OrderedDict([('syllables',
#                                           OrderedDict([('start_times',
#                                                         [349.04,
#                                                          390.04,
#                                                          422.44,
#                                                          440.06,
#                                                          444.56,
#                                                          459.94,
#                                                          477.84,
#                                                          498.46,
#                                                          515.98,
#                                                          525.54,
#                                                          537.52,
#                                                          553.94,
#                                                          554.48,
#                                                          571.06,
#                                                          571.74,
#                                                          578.72,
#                                                          579.78,
#                                                          589.28,
#                                                          604.32,
#                                                          615.46,
#                                                          632.34,
#                                                          652.58,
#                                                          688.6,
#                                                          706.24,
#                                                          721.8,
#                                                          737.42,
#                                                          760.92,
#                                                          766.02,
#                                                          768.08,
#                                                          779.88,
#                                                          781.0,
#                                                          800.88,
#                                                          804.9,
#                                                          813.58,
#                                                          826.24,
#                                                          828.92,
#                                                          844.84,
#                                                          862.46,
#                                                          885.6,
#                                                          903.62,
#                                                          918.42,
#                                                          920.26,
#                                                          937.96,
#                                                          949.26,
#                                                          963.78,
#                                                          969.98,
#                                                          978.78,
#                                                          991.3,
#                                                          1003.92,
#                                                          1012.08,
#                                                          1014.1,
#                                                          1015.86,
#                                                          1031.52,
#                                                          1043.46,
#                                                          1045.16,
#                                                          1050.42,
#                                                          1052.56,
#                                                          1055.94,
#                                                          1061.64,
#                                                          1084.5,
#                                                          1104.28,
#                                                          1124.94,
#                                                          1144.32,
#                                                          1442.94]),
#                                                        ('end_times',
#                                                         [350.98,
#                                                          391.94,
#                                                          425.08,
#                                                          440.92,
#                                                          447.08,
#                                                          462.78,
#                                                          480.72,
#                                                          501.14,
#                                                          518.5,
#                                                          527.92,
#                                                          541.22,
#                                                          554.46,
#                                                          557.4,
#                                                          571.58,
#                                                          574.08,
#                                                          579.48,
#                                                          582.52,
#                                                          592.7,
#                                                          607.48,
#                                                          618.72,
#                                                          636.24,
#                                                          655.66,
#                                                          691.0,
#                                                          709.5,
#                                                          725.4,
#                                                          740.94,
#                                                          765.46,
#                                                          767.42,
#                                                          770.84,
#                                                          780.62,
#                                                          784.64,
#                                                          804.82,
#                                                          806.5,
#                                                          818.04,
#                                                          828.64,
#                                                          831.56,
#                                                          848.24,
#                                                          866.36,
#                                                          889.28,
#                                                          907.04,
#                                                          919.3,
#                                                          924.2,
#                                                          941.48,
#                                                          953.1,
#                                                          967.84,
#                                                          970.6,
#                                                          982.5,
#                                                          995.12,
#                                                          1008.36,
#                                                          1012.84,
#                                                          1015.62,
#                                                          1021.04,
#                                                          1035.84,
#                                                          1044.48,
#                                                          1048.76,
#                                                          1051.92,
#                                                          1054.08,
#                                                          1057.34,
#                                                          1066.46,
#                                                          1089.08,
#                                                          1109.08,
#                                                          1129.58,
#                                                          1148.1,
#                                                          1443.44])]))]))]))])

# %%
len(dataset.data_files)
# Out:
# 128

# %% [markdown]
# #### Create dataset based upon JSON

# %%
from joblib import Parallel, delayed
n_jobs = -1; verbosity = 10

# %%
with Parallel(n_jobs=n_jobs, verbose=verbosity) as parallel:
    syllable_dfs = parallel(
        delayed(create_label_df)(
            dataset.data_files[key].data,
            hparams=dataset.hparams,
            labels_to_retain=[],
            unit="syllables",
            dict_features_to_retain = [],
            key = key,
        )
        for key in tqdm(dataset.data_files.keys())
    )
syllable_df = pd.concat(syllable_dfs)
len(syllable_df)
# Out:
# HBox(children=(IntProgress(value=0, max=128), HTML(value='')))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1911s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  81 out of 128 | elapsed:    1.1s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  94 out of 128 | elapsed:    1.2s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 107 out of 128 | elapsed:    1.2s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 128 out of 128 | elapsed:    1.2s finished
# 10333

# %%
syllable_df[:3]
# Out:
#    start_time  end_time indv  indvi                    key
# 0      349.04    350.98  UNK      0  20170912-070002_01_ch
# 1      390.04    391.94  UNK      0  20170912-070002_01_ch
# 2      422.44    425.08  UNK      0  20170912-070002_01_ch

# %% [markdown]
# ### get audio for dataset

# %%
def get_row_audio(syllable_df, wav_loc, hparams):
    """ load audio and grab individual syllables
    TODO: for large sparse WAV files, the audio should be loaded only for the syllable
    """

    # load audio
    data, rate  = librosa.core.load(wav_loc, sr = None)
    #data = np.nan_to_num(data)
    # get audio for each syllable
    syllable_df["audio"] = [
        data[int(st * rate) : int(et * rate)]
        for st, et in zip(syllable_df.start_time.values, syllable_df.end_time.values)
    ]
    
    syllable_df["rate"] = rate

    return syllable_df

# %%
with Parallel(n_jobs=n_jobs, verbose=verbosity) as parallel:
    syllable_dfs = parallel(
        delayed(get_row_audio)(
            syllable_df[syllable_df.key == key], 
            dataset.data_files[key].data['wav_loc'], 
            dataset.hparams
        )
        for key in tqdm(syllable_df.key.unique())
    )
syllable_df = pd.concat(syllable_dfs)
len(syllable_df)
# Out:
# HBox(children=(IntProgress(value=0, max=128), HTML(value='')))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done  94 out of 128 | elapsed:    9.1s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done 107 out of 128 | elapsed:   10.2s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done 120 out of 128 | elapsed:   11.5s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 128 out of 128 | elapsed:   12.7s finished
# 10333

# %%
df_mask  = np.array([len(i) > 0 for i in tqdm(syllable_df.audio.values)])
# Out:
# HBox(children=(IntProgress(value=0, max=10333), HTML(value='')))

# %%
syllable_df = syllable_df[np.array(df_mask)]

# %%
syllable_df[:3]
# Out:
#    start_time  end_time indv  indvi                    key  \
# 0      349.04    350.98  UNK      0  20170912-070002_01_ch
# 1      390.04    391.94  UNK      0  20170912-070002_01_ch
# 2      422.44    425.08  UNK      0  20170912-070002_01_ch
#
#                                                audio   rate
# 0  [0.00036621094, 0.00024414062, 0.0004272461, 0...  16000
# 1  [-0.00015258789, 9.1552734e-05, 0.0005187988, ...  16000
# 2  [0.0004272461, 9.1552734e-05, 0.0, -0.00036621...  16000

# %%
aud_max = [np.max(np.abs(i)) for i in syllable_df.audio.values]

# %%
plt.hist(aud_max, bins= 50);

# %%
np.sum(np.array(aud_max)  > 0.01)
# Out:
# 9220

# %%
df_mask  = np.array(aud_max)  > 0.01

# %%
syllable_df = syllable_df[np.array(df_mask)]

# %%
sylls = syllable_df.audio.values

# %%
nrows = 10
ncols = 20
zoom = 2
fig, axs = plt.subplots(ncols=ncols, nrows = nrows,figsize = (ncols*zoom, nrows+zoom/1.5))
for i, syll in tqdm(enumerate(sylls), total = nrows*ncols):
    ax = axs.flatten()[i]
    ax.plot(syll)
    if i == nrows*ncols -1:
        break
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))

# %%
syllable_df['audio'] = [i/np.max(np.abs(i)) for i in syllable_df.audio.values]

# %% [markdown]
# ### Create spectrograms

# %%
from avgn.visualization.spectrogram import draw_spec_set
from avgn.signalprocessing.create_spectrogram_dataset import make_spec, mask_spec, log_resize_spec, pad_spectrogram

# %%
syllables_wav = syllable_df.audio.values
syllables_rate = syllable_df.rate.values

# %%
with Parallel(n_jobs=n_jobs, verbose=verbosity) as parallel:
    # create spectrograms
    syllables_spec = parallel(
        delayed(make_spec)(
            syllable,
            rate,
            hparams=dataset.hparams,
            mel_matrix=dataset.mel_matrix,
            use_mel=True,
            use_tensorflow=False,
        )
        for syllable, rate in tqdm(
            zip(syllables_wav, syllables_rate),
            total=len(syllables_rate),
            desc="getting syllable spectrograms",
            leave=False,
        )
    )
# Out:
# HBox(children=(IntProgress(value=0, description='getting syllable spectrograms', max=9220, style=ProgressStyle…
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0623s.) Setting batch_size=6.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 342 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 558 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 672 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 798 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 924 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 1062 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 1200 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done 1350 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done 1500 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done 1662 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done 1824 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 1998 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done 2172 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 2358 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done 2544 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done 2742 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 2940 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 3150 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 3360 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 3582 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 3804 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 4038 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 4272 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 4518 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-1)]: Done 4764 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done 5022 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done 5280 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done 5550 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done 5820 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=-1)]: Done 6102 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done 6384 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done 6678 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=-1)]: Done 6972 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=-1)]: Done 7278 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done 7584 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done 7902 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=-1)]: Done 8220 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=-1)]: Done 8550 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done 8880 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done 9220 out of 9220 | elapsed:   33.9s finished

# %% [markdown]
# ### Rescale spectrogram
# - using log rescaling

# %%
log_scaling_factor = 4

# %%
with Parallel(n_jobs=n_jobs, verbose=verbosity) as parallel:
    syllables_spec = parallel(
        delayed(log_resize_spec)(spec, scaling_factor=log_scaling_factor)
        for spec in tqdm(syllables_spec, desc="scaling spectrograms", leave=False)
    )
# Out:
# HBox(children=(IntProgress(value=0, description='scaling spectrograms', max=9220, style=ProgressStyle(descript…
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0126s.) Setting batch_size=30.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1317s.) Setting batch_size=90.
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 558 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 1008 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 1578 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 3108 tasks      | elapsed:    1.9s
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0267s.) Setting batch_size=45.
# [Parallel(n_jobs=-1)]: Done 4818 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 9220 out of 9220 | elapsed:    9.6s finished

# %%
draw_spec_set(syllables_spec, zoom=1, maxrows=10, colsize=25)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %% [markdown]
# ### Pad spectrograms

# %%
syll_lens = [np.shape(i)[1] for i in syllables_spec]
pad_length = np.max(syll_lens)

# %%
syllable_df[:3]
# Out:
#    start_time  end_time indv  indvi                    key  \
# 0      349.04    350.98  UNK      0  20170912-070002_01_ch
# 1      390.04    391.94  UNK      0  20170912-070002_01_ch
# 2      422.44    425.08  UNK      0  20170912-070002_01_ch
#
#                                                audio   rate
# 0  [0.015189873, 0.010126582, 0.017721519, 0.0303...  16000
# 1  [-0.0049751243, 0.0029850747, 0.016915424, 0.0...  16000
# 2  [0.0069101676, 0.0014807503, 0.0, -0.005923001...  16000

# %%
import seaborn as sns

# %%
for indv in np.unique(syllable_df.indv):
    sns.distplot(np.log(syllable_df[syllable_df.indv==indv]["end_time"]), label=indv)
plt.legend()

# %%
with Parallel(n_jobs=n_jobs, verbose=verbosity) as parallel:

    syllables_spec = parallel(
        delayed(pad_spectrogram)(spec, pad_length)
        for spec in tqdm(
            syllables_spec, desc="padding spectrograms", leave=False
        )
    )
# Out:
# HBox(children=(IntProgress(value=0, description='padding spectrograms', max=9220, style=ProgressStyle(descript…
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0289s.) Setting batch_size=12.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0928s.) Setting batch_size=50.
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 432 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 674 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1956s.) Setting batch_size=102.
# [Parallel(n_jobs=-1)]: Done 1524 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 2474 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 3840 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 9220 out of 9220 | elapsed:    1.2s finished

# %%
draw_spec_set(syllables_spec, zoom=1, maxrows=10, colsize=25)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
np.shape(syllables_spec)
# Out:
# (9220, 32, 34)

# %%
syllable_df['spectrogram'] = syllables_spec

# %%
def norm(x):
    return (x - np.min(x)) / (np.max(x) - np.min(x))

# %%
# convert to uint8 to save space
syllable_df['spectrogram'] = [((i)*255).astype('uint8') for i in syllables_spec]

# %%
syllable_df[:3]
# Out:
#    start_time  end_time indv  indvi                    key  \
# 0      349.04    350.98  UNK      0  20170912-070002_01_ch
# 1      390.04    391.94  UNK      0  20170912-070002_01_ch
# 2      422.44    425.08  UNK      0  20170912-070002_01_ch
#
#                                                audio   rate  \
# 0  [0.015189873, 0.010126582, 0.017721519, 0.0303...  16000
# 1  [-0.0049751243, 0.0029850747, 0.016915424, 0.0...  16000
# 2  [0.0069101676, 0.0014807503, 0.0, -0.005923001...  16000
#
#                                          spectrogram
# 0  [[0, 0, 0, 62, 49, 50, 56, 51, 53, 47, 49, 52,...
# 1  [[0, 0, 0, 40, 47, 40, 40, 43, 42, 37, 42, 33,...
# 2  [[0, 0, 0, 11, 19, 25, 27, 25, 19, 11, 7, 8, 2...

# %% [markdown]
# ### view syllables per indv

# %%
syllable_df.indv.unique()
# Out:
# array(['UNK'], dtype=object)

# %%
for indv in np.sort(syllable_df.indv.unique()):
    print(indv, np.sum(syllable_df.indv == indv))
    specs = np.array([i/np.max(i) for i in syllable_df[syllable_df.indv == indv].spectrogram.values])
    specs[specs<0] = 0
    draw_spec_set(specs, zoom=2,
                  maxrows=16, 
                  colsize=25)
# Out:
# UNK 9220
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %% [markdown]
# ### save dataset

# %%
save_loc = DATA_DIR / 'syllable_dfs' / DATASET_ID / 'gibbon.pickle'
ensure_dir(save_loc)
syllable_df.to_pickle(save_loc)
