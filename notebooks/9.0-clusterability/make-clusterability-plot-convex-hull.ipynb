# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from avgn.utils.paths import DATA_DIR, most_recent_subdirectory, ensure_dir
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
import seaborn as sns

# %%
from avgn.dataset_names import species_dict

# %%
hopkins_dfs = list(DATA_DIR.glob('clusterability/convex_sample/*.pickle'))
hopkins_dfs[:3]
# Out:
# [PosixPath('/local/home/tsainbur/github_repos/avgn_paper/data/clusterability/convex_sample/katahira_white_munia_segmented_ WM15.pickle'),
#  PosixPath('/local/home/tsainbur/github_repos/avgn_paper/data/clusterability/convex_sample/BIRD_DB_Toxostoma_redivivum_ CATH-TLR12.pickle'),
#  PosixPath('/local/home/tsainbur/github_repos/avgn_paper/data/clusterability/convex_sample/katahira_white_munia_segmented_ WM39.pickle')]

# %%
clusterability_df = pd.concat([pd.read_pickle(i) for i in tqdm(hopkins_dfs)])
# Out:
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))

# %%
clusterability_df[:3]
# Out:
#                                                   df  \
# 0  /local/home/tsainbur/github_repos/avgn_paper/d...
# 0  /local/home/tsainbur/github_repos/avgn_paper/d...
# 0  /local/home/tsainbur/github_repos/avgn_paper/d...
#
#                           dataset        indv  umap_hopkins_1  umap_hopkins_10
# 0  katahira_white_munia_segmented        WM15        0.991037         0.984286
# 0     BIRD_DB_Toxostoma_redivivum  CATH-TLR12        0.977366         0.942669
# 0  katahira_white_munia_segmented        WM39        0.983414         0.988824

# %%
clusterability_df
# Out:
#                                                    df  \
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# ..                                                ...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
# 0   /local/home/tsainbur/github_repos/avgn_paper/d...
#
#                                 dataset        indv  umap_hopkins_1  \
# 0        katahira_white_munia_segmented        WM15        0.991037
# 0           BIRD_DB_Toxostoma_redivivum  CATH-TLR12        0.977366
# 0        katahira_white_munia_segmented        WM39        0.983414
# 0        katahira_white_munia_segmented        WM38        0.978069
# 0        katahira_white_munia_segmented        WM25        0.925494
# 0        katahira_white_munia_segmented        WM23        0.991915
# 0       castellucci_mouse_usv_segmented      VOC594        0.841422
# 0           BIRD_DB_Toxostoma_redivivum   CATH-TLR8        0.988494
# 0         zebra_finch_gardner_segmented        lr12        0.992731
# 0        katahira_white_munia_segmented        WM19        0.973486
# 0           BIRD_DB_Toxostoma_redivivum  CATH-TLR10        0.876431
# 0                 bengalese_finch_sober    bl26lb16        0.996315
# 0                BIRD_DB_Vireo_cassinii        full        0.993212
# 0        katahira_white_munia_segmented        WM18        0.991609
# 0        katahira_white_munia_segmented        WM07        0.988184
# 0                      canary_segmented       bird4        0.995012
# 0        katahira_white_munia_segmented        WM35        0.980993
# 0   european_starling_gentner_segmented       b1125        0.973478
# 0                      canary_segmented       bird1        0.994295
# 0               koumura_bengalese_finch       Bird0        0.994633
# 0                 bengalese_finch_sober      gy6or6        0.996661
# 0   european_starling_gentner_segmented       b1076        0.988005
# 0        katahira_white_munia_segmented        WM22        0.927823
# 0                      canary_segmented       bird3        0.994977
# 0               koumura_bengalese_finch       Bird5        0.994943
# 0               gibbon_morita_segmented        full        0.910104
# 0                         swamp_sparrow        full        0.989766
# 0        katahira_white_munia_segmented        WM17        0.993450
# 0        katahira_white_munia_segmented        WM16        0.976143
# 0               koumura_bengalese_finch       Bird4        0.994378
# ..                                  ...         ...             ...
# 0        katahira_white_munia_segmented        WM09        0.969667
# 0         zebra_finch_gardner_segmented        lr77        0.993994
# 0                     batsong_segmented        full        0.970419
# 0   european_starling_gentner_segmented       b1077        0.991373
# 0       castellucci_mouse_usv_segmented      VOC592        0.838630
# 0        katahira_white_munia_segmented        WM13        0.992238
# 0        katahira_white_munia_segmented        WM43        0.792102
# 0               koumura_bengalese_finch       Bird1        0.995212
# 0        katahira_white_munia_segmented        WM42        0.942289
# 0         zebra_finch_gardner_segmented        lr28        0.992993
# 0        katahira_white_munia_segmented        WM24        0.726876
# 0              mobysound_humpback_whale        full        0.864112
# 0           BIRD_DB_Toxostoma_redivivum   CATH-TLR7        0.922064
# 0        katahira_white_munia_segmented        WM01        0.992232
# 0   european_starling_gentner_segmented       b1053        0.988967
# 0        katahira_white_munia_segmented        WM44        0.966296
# 0       castellucci_mouse_usv_segmented      VOC597        0.848424
# 0        katahira_white_munia_segmented        WM26        0.965092
# 0        katahira_white_munia_segmented        WM10        0.985796
# 0                 bengalese_finch_sober    gr41rd51        0.996347
# 0   european_starling_gentner_segmented       b1143        0.969435
# 0         zebra_finch_gardner_segmented       lny64        0.993527
# 0           BIRD_DB_Toxostoma_redivivum    CATH-CP1        0.982594
# 0        katahira_white_munia_segmented        WM32        0.978962
# 0        katahira_white_munia_segmented        WM05        0.992625
# 0        katahira_white_munia_segmented        WM03        0.992956
# 0        katahira_white_munia_segmented        WM36        0.981668
# 0        katahira_white_munia_segmented        WM31        0.979818
# 0                      canary_segmented       bird6        0.994718
# 0           BIRD_DB_Toxostoma_redivivum   CATH-TLR9        0.933802
#
#     umap_hopkins_10              species    family
# 0          0.984286   White-rumped munia  songbird
# 0          0.942669  California thrasher  songbird
# 0          0.988824   White-rumped munia  songbird
# 0          0.979977   White-rumped munia  songbird
# 0          0.883147   White-rumped munia  songbird
# 0          0.990352   White-rumped munia  songbird
# 0          0.856892                Mouse    mammal
# 0          0.985530  California thrasher  songbird
# 0          0.992591          Zebra finch  songbird
# 0          0.980407   White-rumped munia  songbird
# 0          0.808160  California thrasher  songbird
# 0          0.996087      Bengalese finch  songbird
# 0          0.993819       Cassin's vireo  songbird
# 0          0.984607   White-rumped munia  songbird
# 0          0.987341   White-rumped munia  songbird
# 0          0.995173               Canary  songbird
# 0          0.970862   White-rumped munia  songbird
# 0          0.983215    European starling  songbird
# 0          0.994031               Canary  songbird
# 0          0.993618      Bengalese finch  songbird
# 0          0.996493      Bengalese finch  songbird
# 0          0.991204    European starling  songbird
# 0          0.950053   White-rumped munia  songbird
# 0          0.994812               Canary  songbird
# 0          0.995011      Bengalese finch  songbird
# 0          0.917176               Gibbon    mammal
# 0          0.990135        Swamp sparrow  songbird
# 0          0.985707   White-rumped munia  songbird
# 0          0.984533   White-rumped munia  songbird
# 0          0.994871      Bengalese finch  songbird
# ..              ...                  ...       ...
# 0          0.960040   White-rumped munia  songbird
# 0          0.992267          Zebra finch  songbird
# 0          0.970278   Egyptian fruit bat    mammal
# 0          0.989560    European starling  songbird
# 0          0.841432                Mouse    mammal
# 0          0.987890   White-rumped munia  songbird
# 0          0.819914   White-rumped munia  songbird
# 0          0.995691      Bengalese finch  songbird
# 0          0.947325   White-rumped munia  songbird
# 0          0.993494          Zebra finch  songbird
# 0          0.763260   White-rumped munia  songbird
# 0          0.856227       Humpback whale    mammal
# 0          0.903679  California thrasher  songbird
# 0          0.994573   White-rumped munia  songbird
# 0          0.989848    European starling  songbird
# 0          0.963862   White-rumped munia  songbird
# 0          0.880178                Mouse    mammal
# 0          0.965489   White-rumped munia  songbird
# 0          0.982363   White-rumped munia  songbird
# 0          0.996316      Bengalese finch  songbird
# 0          0.977989    European starling  songbird
# 0          0.992710          Zebra finch  songbird
# 0          0.980866  California thrasher  songbird
# 0          0.978050   White-rumped munia  songbird
# 0          0.991946   White-rumped munia  songbird
# 0          0.989867   White-rumped munia  songbird
# 0          0.980273   White-rumped munia  songbird
# 0          0.976903   White-rumped munia  songbird
# 0          0.994817               Canary  songbird
# 0          0.954250  California thrasher  songbird
#
# [98 rows x 7 columns]

# %%
clusterability_df['species'] = [species_dict[ds]['species']  for ds in clusterability_df['dataset'].values]
clusterability_df['family'] = [species_dict[ds]['group']  for ds in clusterability_df['dataset'].values]

# %%
from avgn.utils.general import save_fig
from avgn.utils.paths import FIGURE_DIR, ensure_dir

# %%
ensure_dir(FIGURE_DIR / 'hopkins')

# %%
sns.set(style='white', font_scale=2)

for metric in ['umap_hopkins_1','umap_hopkins_10']:
    fig, ax = plt.subplots(ncols=1, figsize=(6.25, 10))

    # log scale
    result = clusterability_df.groupby(["species", 'family'])[metric].aggregate(
        np.median).reset_index().sort_values(metric)#, ascending=False)
    result[metric] = (1 - result[metric])

    # create bar chart
    bar = sns.barplot(
        x=metric,
        y="species",
        hue='family',
        dodge=False,
        data=result,
        ax=ax,
        linewidth=3,
        edgecolor="0",
        order=result['species'],
        #log=True,
        #width = 1,
        palette = sns.color_palette('Set1')
    )
    ax.set_xlabel('Clusterability ($\it{Hopkin\'s\ statistic}$)', fontsize=24)
    ax.set_ylabel('')
    ax.get_legend().remove()

    for axis in ['top','left','right']:
        ax.spines[axis].set_linewidth(0)
    ax.spines['bottom'].set_linewidth(5)
    ax.set_xscale('log')

    ylim = ax.get_ylim()
    ax.set_ylim([ylim[0]+.25, ylim[1]])
    #ax.set_xlim([0.5,1])

    save_fig(FIGURE_DIR / 'hopkins' / ('hopkins_comparison_'+ metric), dpi=300, save_jpg=False, save_png=True)
