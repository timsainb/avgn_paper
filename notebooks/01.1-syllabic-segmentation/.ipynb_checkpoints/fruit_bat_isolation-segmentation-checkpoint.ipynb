# %% [markdown]
# ### this segmentation is a sub-segmentation of the original segmentations provided by the dataset

# %% [markdown]
# 1) create a dataset of syllable waveforms for each isolation segment
#
# 2) get segmented times for each syllable in that segment
#
# 3) create a new dataframe with the isolated syllables

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm.autonotebook import tqdm
from joblib import Parallel, delayed
import umap
import pandas as pd
from datetime import datetime

# %%
from avgn.utils.paths import DATA_DIR, most_recent_subdirectory, ensure_dir

# %%
DATASET_ID = 'batsong'

# %%
# create a unique datetime identifier for the files output by this notebook
DT_ID = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
DT_ID
# Out:
# '2019-10-08_21-41-00'

# %%
from avgn.utils.hparams import HParams
from avgn.dataset import DataSet

# %%
from avgn.signalprocessing.create_spectrogram_dataset import prepare_wav, create_label_df, get_row_audio

# %% [markdown]
# ### create dataset

# %%
hparams = HParams(
    num_mel_bins = 32,
    mel_lower_edge_hertz=500,
    mel_upper_edge_hertz=120000,
    butter_lowcut = 500,
    butter_highcut = 120000,
    ref_level_db = 20,
    min_level_db = -60,
    mask_spec = True,
    win_length_ms = 0.5,
    hop_length_ms = 0.05,
    mask_spec_kwargs = {"spec_thresh": 0.9, "offset": 1e-10},
    n_jobs = -1,
    verbosity=1,
    nex = -1
)

# %%
# create a dataset object
dataset = DataSet(DATASET_ID, hparams = hparams)
# Out:
# HBox(children=(IntProgress(value=0, description='loading json', max=83884, style=ProgressStyle(description_wid…
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 1313 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 3063 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 5513 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 8663 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done 12513 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=-1)]: Done 17063 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done 22313 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=-1)]: Done 28251 tasks      | elapsed:   40.1s
# [Parallel(n_jobs=-1)]: Done 34901 tasks      | elapsed:   48.2s
# [Parallel(n_jobs=-1)]: Done 42251 tasks      | elapsed:   57.0s
# [Parallel(n_jobs=-1)]: Done 50301 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 59051 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 68501 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 78651 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 83884 out of 83884 | elapsed:  1.8min finished
# HBox(children=(IntProgress(value=0, description='getting unique individuals', max=83884, style=ProgressStyle(d…

# %%
# dataset.data_files = {i:dataset.data_files[i] for i in list(dataset.data_files.keys())[:5]}

# %%
dataset.sample_json
# Out:
# OrderedDict([('fid', 253810),
#              ('Treatment ID', 17),
#              ('Recording channel', 1),
#              ('Recording time', '2013-05-06 07:03:32'),
#              ('indvs',
#               OrderedDict([('210',
#                             OrderedDict([('syllables',
#                                           OrderedDict([('start_times',
#                                                         [4e-06]),
#                                                        ('end_times',
#                                                         [1.314112]),
#                                                        ('addressee', [207]),
#                                                        ('context',
#                                                         ['General']),
#                                                        ('emit_prevoc_act',
#                                                         [2]),
#                                                        ('add_prevoc_act', [2]),
#                                                        ('emit_postvoc_act',
#                                                         [3]),
#                                                        ('add_postvoc_act',
#                                                         [3])]))]))])),
#              ('species', 'Rousettus aegyptiacus'),
#              ('common_name', 'Egyptian fruit bat'),
#              ('samplerate_hz', 250000),
#              ('original_wav',
#               '/mnt/cube/tsainbur/Projects/github_repos/avgn_paper/data/raw/batsong/zip_contents/files221/130506064422924720.WAV'),
#              ('length_s', 1.314112),
#              ('wav_loc',
#               '/mnt/cube/tsainbur/Projects/github_repos/avgn_paper/data/raw/batsong/zip_contents/files221/130506064422924720.WAV')])

# %%
len(dataset.data_files)
# Out:
# 83884

# %% [markdown]
# #### Create dataset based upon JSON

# %%
from joblib import Parallel, delayed
n_jobs = -1; verbosity = 10

# %%
with Parallel(n_jobs=n_jobs, verbose=verbosity) as parallel:
    syllable_dfs = parallel(
        delayed(create_label_df)(
            dataset.data_files[key].data,
            hparams=dataset.hparams,
            labels_to_retain=["context"],
            unit="syllables",
            dict_features_to_retain = [],
            key = key,
        )
        for key in tqdm(dataset.data_files.keys())
    )
syllable_df = pd.concat(syllable_dfs)
len(syllable_df)
# Out:
# HBox(children=(IntProgress(value=0, max=83884), HTML(value='')))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0381s.) Setting batch_size=10.
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1761s.) Setting batch_size=22.
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 422 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 708 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1038 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 1368 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 1742 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 2116 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 2534 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 2700 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 3162 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 3624 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 4130 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done 4636 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 5186 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done 5736 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 6330 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 6924 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 7562 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 8200 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 8882 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 9564 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 10290 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 11016 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 11786 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done 12556 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done 13370 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=-1)]: Done 14184 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0049s.) Setting batch_size=11.
# [Parallel(n_jobs=-1)]: Done 15042 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done 15537 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done 15988 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done 16439 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 16912 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done 17385 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=-1)]: Done 17880 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=-1)]: Done 18375 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done 18892 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=-1)]: Done 19409 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 19948 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=-1)]: Done 20487 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=-1)]: Done 21048 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done 21609 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-1)]: Done 22192 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 22775 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done 23380 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 23985 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done 24612 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 25239 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=-1)]: Done 25888 tasks      | elapsed:   34.6s
# [Parallel(n_jobs=-1)]: Done 26537 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done 27208 tasks      | elapsed:   36.2s
# [Parallel(n_jobs=-1)]: Done 27879 tasks      | elapsed:   37.1s
# [Parallel(n_jobs=-1)]: Done 28572 tasks      | elapsed:   38.0s
# [Parallel(n_jobs=-1)]: Done 29265 tasks      | elapsed:   38.9s
# [Parallel(n_jobs=-1)]: Done 29980 tasks      | elapsed:   39.8s
# [Parallel(n_jobs=-1)]: Done 30695 tasks      | elapsed:   40.7s
# [Parallel(n_jobs=-1)]: Done 31432 tasks      | elapsed:   41.8s
# [Parallel(n_jobs=-1)]: Done 32169 tasks      | elapsed:   42.8s
# [Parallel(n_jobs=-1)]: Done 32928 tasks      | elapsed:   43.8s
# [Parallel(n_jobs=-1)]: Done 33687 tasks      | elapsed:   44.9s
# [Parallel(n_jobs=-1)]: Done 34468 tasks      | elapsed:   45.9s
# [Parallel(n_jobs=-1)]: Done 35249 tasks      | elapsed:   48.4s
# [Parallel(n_jobs=-1)]: Done 36052 tasks      | elapsed:   49.4s
# [Parallel(n_jobs=-1)]: Done 36855 tasks      | elapsed:   50.5s
# [Parallel(n_jobs=-1)]: Done 37680 tasks      | elapsed:   51.6s
# [Parallel(n_jobs=-1)]: Done 38505 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done 39352 tasks      | elapsed:   53.8s
# [Parallel(n_jobs=-1)]: Done 40199 tasks      | elapsed:   54.8s
# [Parallel(n_jobs=-1)]: Done 41068 tasks      | elapsed:   55.9s
# [Parallel(n_jobs=-1)]: Done 41937 tasks      | elapsed:   57.1s
# [Parallel(n_jobs=-1)]: Done 42828 tasks      | elapsed:   58.2s
# [Parallel(n_jobs=-1)]: Done 43719 tasks      | elapsed:   59.4s
# [Parallel(n_jobs=-1)]: Done 44632 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 45545 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 46480 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 47415 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 48372 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 49329 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 50308 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 51287 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 52288 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 53289 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 54312 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 55335 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 56380 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 57425 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 58492 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0120s.) Setting batch_size=5.
# [Parallel(n_jobs=-1)]: Done 59403 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 59898 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 60393 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 60898 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 61403 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 61918 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 62433 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 62958 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 63483 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 64018 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 64553 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 65098 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 65643 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 66198 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 66753 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 67318 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 67883 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 68458 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 69033 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 69618 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 70203 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 70798 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 71393 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 71998 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 72603 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 73218 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 73833 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 74458 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 75083 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 75718 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 76353 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 76998 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 77643 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 78298 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 78953 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 79618 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 80283 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 80958 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 81633 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 82318 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 83003 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 83698 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 83884 out of 83884 | elapsed:  1.9min finished
# 86867

# %%
syllable_df[:3]
# Out:
#    start_time  end_time   context  indv  indvi                 key
# 0    0.000004  1.314112   General   210      0  130506064422924720
# 0    0.000004  2.133312  Sleeping  -216      0  130126055734753855
# 0    0.000004  1.314112  Sleeping   207      0  130529075332772067

# %%
syllable_df.context.unique()
# Out:
# array(['General', 'Sleeping', 'Biting', 'Isolation', 'Feeding',
#        'Mating protest', 'Fighting', 'Grooming', 'Kissing', 'Separation',
#        'Unknown', 'Threat-like', 'Landing'], dtype=object)

# %%
# get only isolation calls
#syllable_df = syllable_df[syllable_df.context == "Isolation"]

# %% [markdown]
# ### get audio for dataset

# %%
with Parallel(n_jobs=n_jobs, verbose=verbosity) as parallel:
    syllable_dfs = parallel(
        delayed(get_row_audio)(
            syllable_df[syllable_df.key == key], 
            dataset.data_files[key].data['wav_loc'], 
            dataset.hparams
        )
        for key in tqdm(syllable_df.key.unique())
    )
syllable_df = pd.concat(syllable_dfs)
len(syllable_df)
# Out:
# HBox(children=(IntProgress(value=0, max=5632), HTML(value='')))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 194 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 217 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 265 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done 290 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 317 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 344 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 373 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 402 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done 433 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 464 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 497 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 530 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 565 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 600 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 637 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 674 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=-1)]: Done 713 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 793 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 834 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 877 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done 920 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done 965 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 1010 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done 1057 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done 1104 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done 1153 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done 1202 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done 1253 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=-1)]: Done 1304 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done 1357 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done 1410 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done 1465 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done 1520 tasks      | elapsed:   28.3s
# [Parallel(n_jobs=-1)]: Done 1577 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done 1634 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done 1693 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done 1752 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done 1813 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=-1)]: Done 1874 tasks      | elapsed:   35.0s
# [Parallel(n_jobs=-1)]: Done 1937 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=-1)]: Done 2000 tasks      | elapsed:   37.0s
# [Parallel(n_jobs=-1)]: Done 2065 tasks      | elapsed:   38.4s
# [Parallel(n_jobs=-1)]: Done 2130 tasks      | elapsed:   39.6s
# [Parallel(n_jobs=-1)]: Done 2197 tasks      | elapsed:   40.9s
# [Parallel(n_jobs=-1)]: Done 2264 tasks      | elapsed:   42.2s
# [Parallel(n_jobs=-1)]: Done 2333 tasks      | elapsed:   43.3s
# [Parallel(n_jobs=-1)]: Done 2402 tasks      | elapsed:   44.5s
# [Parallel(n_jobs=-1)]: Done 2473 tasks      | elapsed:   45.6s
# [Parallel(n_jobs=-1)]: Done 2544 tasks      | elapsed:   46.8s
# [Parallel(n_jobs=-1)]: Done 2617 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=-1)]: Done 2690 tasks      | elapsed:   49.0s
# [Parallel(n_jobs=-1)]: Done 2765 tasks      | elapsed:   50.2s
# [Parallel(n_jobs=-1)]: Done 2840 tasks      | elapsed:   52.1s
# [Parallel(n_jobs=-1)]: Done 2917 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=-1)]: Done 2994 tasks      | elapsed:   54.7s
# [Parallel(n_jobs=-1)]: Done 3073 tasks      | elapsed:   56.1s
# [Parallel(n_jobs=-1)]: Done 3152 tasks      | elapsed:   57.3s
# [Parallel(n_jobs=-1)]: Done 3233 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=-1)]: Done 3314 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 3397 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 3480 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 3565 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 3650 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 3737 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 3824 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 3913 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 4002 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 4093 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 4184 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 4277 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 4370 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 4465 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 4560 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 4657 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 4754 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 4853 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 4952 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 5053 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 5154 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 5257 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 5360 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 5465 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 5570 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 5632 out of 5632 | elapsed:  1.7min finished
# 5681

# %%
df_mask  = np.array([len(i) > 0 for i in tqdm(syllable_df.audio.values)])
# Out:
# HBox(children=(IntProgress(value=0, max=5681), HTML(value='')))

# %%
syllable_df = syllable_df[np.array(df_mask)]

# %%
syllable_df[:3]
# Out:
#    start_time  end_time    context indv  indvi                 key  \
# 0    0.000004  2.231616  Isolation    0      0  121202234934171138
# 0    0.912780  2.100544  Isolation    0      0  120717011305685619
# 0    0.000004  2.886976  Isolation    0      0  121122011905590119
#
#                                                audio    rate
# 0  [0.00021063547800872386, 0.0001627990693820472...  250000
# 0  [-1.6845749088512945e-05, 0.000183535147472987...  250000
# 0  [0.00010221735009936458, 0.0005975149564042161...  250000

# %%
sylls = syllable_df.audio.values

# %%
nrows = 5
ncols = 10
zoom = 2
fig, axs = plt.subplots(ncols=ncols, nrows = nrows,figsize = (ncols*zoom, nrows+zoom/1.5))
for i, syll in tqdm(enumerate(sylls), total = nrows*ncols):
    ax = axs.flatten()[i]
    ax.plot(syll)
    if i == nrows*ncols -1:
        break
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))

# %%
syllable_df['audio'] = [i/np.max(i) for i in tqdm(syllable_df.audio.values)]
# Out:
# HBox(children=(IntProgress(value=0, max=5681), HTML(value='')))

# %% [markdown]
# ### segment isolation calls

# %%
from vocalseg.dynamic_thresholding import dynamic_threshold_segmentation
from vocalseg.dynamic_thresholding import plot_segmented_spec, plot_segmentations
from vocalseg.utils import butter_bandpass_filter, spectrogram, int16tofloat32, plot_spec

# %%
len(syllable_df)
# Out:
# 5681

# %%
syllable_df[:3]
# Out:
#    start_time  end_time    context indv  indvi                 key  \
# 0    0.000004  2.231616  Isolation    0      0  121202234934171138
# 0    0.912780  2.100544  Isolation    0      0  120717011305685619
# 0    0.000004  2.886976  Isolation    0      0  121122011905590119
#
#                                                audio    rate
# 0  [0.003508107760247807, 0.0027113983079176587, ...  250000
# 0  [-0.0001211340214402708, 0.001319760277338829,...  250000
# 0  [0.0014052120669945686, 0.008214214378799059, ...  250000

# %%
pd.DataFrame({i: [np.sum(i == syllable_df.indv)] for i in syllable_df.indv.unique()}).T.sort_values(by=0, ascending=False).T
# Out:
#       0  211  111  216  220  221  230  115  207  108  ...  226  -108  119  \
# 0  3521  362  319  234  207  155  135  127  113   97  ...    1     1    1
#
#    110  225  218  203  -211  -231  228
# 0    1    1    1    1     1     1    1
#
# [1 rows x 30 columns]

# %%
n_fft=1024
hop_length_ms=.5
win_length_ms=4
ref_level_db=20
pre=0.97
min_level_db=-30
silence_threshold = 0.1
min_silence_for_spec=0.1
max_vocal_for_spec=1.0,
min_syllable_length_s = 0.01
spectral_range = [5000, 60000]

# %%
import warnings
warnings.filterwarnings('ignore')

display_results=False
start_times = []
end_times = []
for idx, row in tqdm(syllable_df.iterrows(), total=len(syllable_df)):
    results = dynamic_threshold_segmentation(
        row.audio,
        row.rate,
        n_fft=n_fft,
        hop_length_ms=hop_length_ms,
        win_length_ms=win_length_ms,
        ref_level_db=ref_level_db,
        pre=pre,
        min_level_db=min_level_db,
        
        silence_threshold=silence_threshold,
        verbose=False,
        spectral_range=spectral_range,
        min_syllable_length_s=min_syllable_length_s,
                min_level_db_floor=20,

    )
    
    if results is None:
        if display_results:
            spec = spectrogram(
                row.audio,
                row.rate,
                n_fft=n_fft,
                hop_length_ms=hop_length_ms,
                win_length_ms=win_length_ms,
                ref_level_db=ref_level_db,
                pre=pre,
                min_level_db=min_level_db,
            )
            fig, ax = plt.subplots(figsize=(30,5))
            plot_spec(spec, fig, ax);
            plt.show()
        start_times.append(None)
        end_times.append(None)
        continue
    else:
        if display_results:
            plot_segmentations(
                results["spec"],
                vocal_envelope=results["vocal_envelope"],
                onsets=results["onsets"],
                offsets=results["offsets"],
                rate=row.rate,
                hop_length_ms=hop_length_ms,
                figsize=(30, 5),
                #spectral_range=spectral_range
            )
            plt.show()
            
    start_times.append(results['onsets'])
    end_times.append(results['offsets'])
# Out:
# HBox(children=(IntProgress(value=0, max=5681), HTML(value='')))
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62c70db0>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62c70990>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62c70990>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62c70bf8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2a40>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# ...
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df2728>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7fdf62df27d8>
# Traceback (most recent call last):
#   File "/mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'

# %%
len((np.concatenate([i for i in start_times if i is not None])))

# %%
results.keys()
# Out:
# dict_keys(['spec', 'vocal_envelope', 'min_level_db', 'onsets', 'offsets'])

# %%
start_times[:3]
# Out:
# [array([1.058 , 1.074 , 1.0845, 1.1255, 1.154 , 1.1795]),
#  array([0.0475, 0.063 , 0.085 , 0.108 , 0.131 , 0.8555, 0.878 , 0.9005]),
#  array([0.206 , 0.2305, 0.3065, 0.336 , 0.363 , 1.0575, 1.1105, 1.1355,
#         1.6955, 1.7225, 1.749 , 1.7755, 1.8025, 2.3955, 2.423 ])]

# %% [markdown]
# ### add start and end times to json

# %%
from avgn.utils.json import NoIndent, NoIndentEncoder

# %%
syllable_df['start_times'] = start_times

# %%
syllable_df['end_times'] = end_times

# %%
syllable_df[:3]
# Out:
#    start_time  end_time    context indv  indvi                 key  \
# 0    0.000004  2.231616  Isolation    0      0  121202234934171138
# 0    0.912780  2.100544  Isolation    0      0  120717011305685619
# 0    0.000004  2.886976  Isolation    0      0  121122011905590119
#
#                                                audio    rate  \
# 0  [0.003508107760247807, 0.0027113983079176587, ...  250000
# 0  [-0.0001211340214402708, 0.001319760277338829,...  250000
# 0  [0.0014052120669945686, 0.008214214378799059, ...  250000
#
#                                          start_times  \
# 0      [1.058, 1.074, 1.0845, 1.1255, 1.154, 1.1795]
# 0  [0.0475, 0.063, 0.085, 0.108, 0.131, 0.8555, 0...
# 0  [0.206, 0.2305, 0.3065, 0.336, 0.363, 1.0575, ...
#
#                                            end_times
# 0        [1.072, 1.084, 1.1245, 1.145, 1.164, 1.195]
# 0  [0.06, 0.082, 0.1055, 0.1285, 0.1415, 0.8665, ...
# 0  [0.2255, 0.3045, 0.3335, 0.3575, 0.384, 1.072,...

# %%
for idx, row in tqdm(syllable_df.iterrows(), total=len(syllable_df)):
    
    if row.start_times is None: 
        continue
    
    new_json = dataset.data_files[row.key].data.copy()
    new_json['indvs'][row.indv]['elements'] = {
        "start_times": NoIndent(list(row.start_times)),
        "end_times": NoIndent(list(row.end_times)),
    }
    json_out = (
        DATA_DIR
        / "processed"
        / (DATASET_ID + '_isolate_segmented')
        / DT_ID
        / "JSON"
        / (row.key + ".JSON")
    )
    
    json_txt = json.dumps(new_json, cls=NoIndentEncoder, indent=2)
    
    ensure_dir(json_out.as_posix())
    print(json_txt, file=open(json_out.as_posix(), "w"))
    #break
# Out:
# HBox(children=(IntProgress(value=0, max=5681), HTML(value='')))
